# %%
from importlib import reload
reload(ex)
reload(plt)

# %%
# %matplotlib inline

import os
import extractor as ex
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing data

# %% [markdown]
#     1. Find correct box

# %%
ex.extract('pdfs/1081_1.pdf', 
           pages=(1,20), 
           box=(1353, 2022, 1479, 2148) ### left, top, right, bottom; record answer to extrator.py -> boxes
          )
raw = ex.raw_data('1081_1')
fig = raw.examine()

# %% [markdown]
#     2. Use `labeler` to label the pictures. (remember to remove people disagree to join)

# %%
raw = ex.raw_data('1081_1')
raw.labeler()

# %%
# !ls 1081_1/

# %% [markdown]
#     3. Or apply the patch directly

# %%
raw = ex.raw_data('1081_1')
raw.labeler(patch='1081_1_patch.csv')

# %% [markdown]
#     4. `merge_to`

# %%
raw = ex.raw_data('1081_1')
raw.merge_to()

# %%
nsysu = ex.raw_data('nsysu-digits')
print(nsysu.df.shape)
nsysu.df.head()

# %%
nsysu.df
